# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data into a Pandas DataFrame
df = pd.read_csv('social_media_data.csv')
pd.set_option('display.max_rows', None)


# Explore the data
print(df.head())
print(df.info())
print(df.describe())
print(df['Category'].value_counts())

# Clean the data
df = df.dropna()
df = df.drop_duplicates()
df['Date'] = pd.to_datetime(df['Date'])
df['Likes'] = df['Likes'].astype(int)

# Visualize the data
sns.histplot(df['Likes'])
plt.show()
sns.boxplot(x='Category', y='Likes', data=df)
plt.show()

# Analyze the data
mean_likes = df['Likes'].mean()
print(f"Mean Likes: {mean_likes:.2f}")

category_likes = df.groupby('Category')['Likes'].mean()
print(category_likes)

# Communicate the insights
# Create a Jupyter Notebook or report to communicate your findings
# Out:
#    ID                                               Text  \
# 0   1  Excited to try out the new product from XYZ Co...
# 1   2  Just got my hands on the new XYZ Corp product ...
# 2   3  Disappointed with the new product from XYZ Cor...
# 3   4  Just attended the product launch event for XYZ...
# 4   5  Mixed feelings about the new product from XYZ ...
#
#                  Username            Location  Followers  Category  Likes  \
# 0     @product_enthusiast    Los Angeles, USA      10000  Positive    563
# 1          @tech_reviewer  San Francisco, USA       5000  Positive    736
# 2  @dissatisfied_customer       New York, USA       2500  Negative     35
# 3         @event_attendee          London, UK       7500   Neutral    587
# 4        @tech_enthusiast     Toronto, Canada       8000     Mixed    500
#
#          Date
# 0  2023-01-10
# 1  2023-01-09
# 2  2023-01-03
# 3  2023-01-01
# 4  2023-01-23
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         14 non-null     int64
#  1   Text       14 non-null     object
#  2   Username   14 non-null     object
#  3   Location   14 non-null     object
#  4   Followers  14 non-null     int64
#  5   Category   14 non-null     object
#  6   Likes      14 non-null     int64
#  7   Date       14 non-null     object
# dtypes: int64(3), object(5)
# memory usage: 1.0+ KB
# None
#               ID     Followers       Likes
# count  14.000000     14.000000   14.000000
# mean    7.571429   6142.857143  337.642857
# std     4.309458   2727.555763  298.736727
# min     1.000000   2500.000000   25.000000
# 25%     4.250000   4250.000000   90.000000
# 50%     7.500000   5500.000000  218.000000
# 75%    10.750000   7875.000000  547.250000
# max    15.000000  10000.000000  950.000000
# Positive    8
# Negative    2
# Neutral     2
# Mixed       2
# Name: Category, dtype: int64
# Mean Likes: 337.64
# Category
# Mixed       393.000
# Negative     57.500
# Neutral     318.500
# Positive    398.625
# Name: Likes, dtype: float64

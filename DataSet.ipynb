# %%
import csv

# Sample tweet data
tweets = [
     {
        'id': 1,
        'text': 'Excited to try out the new product from XYZ Corp! #innovation #productlaunch',
        'username': '@product_enthusiast',
        'location': 'Los Angeles, USA',
        'followers': 10000,
        'category': 'Positive',
        'likes': 563,
         'date': '2023-01-10'
    },
    {
        'id': 2,
        'text': 'Just got my hands on the new XYZ Corp product and it looks amazing! Can\'t wait to try it out. #excited #productlaunch',
        'username': '@tech_reviewer',
        'location': 'San Francisco, USA',
        'followers': 5000,
        'category': 'Positive',
        'likes': 736,
        'date': '2023-01-09'
    },
    {
        'id': 3,
        'text': 'Disappointed with the new product from XYZ Corp. It doesn\'t work as advertised. #disappointed #productlaunch',
        'username': '@dissatisfied_customer',
        'location': 'New York, USA',
        'followers': 2500,
        'category': 'Negative',
        'likes': 35,
        'date': '2023-01-03'
    },
    {
        'id': 4,
        'text': 'Just attended the product launch event for XYZ Corp. The new product looks impressive and I can\'t wait to see what else they have in store. #productlaunch #tech',
        'username': '@event_attendee',
        'location': 'London, UK',
        'followers': 7500,
        'category': 'Neutral',
        'likes': 587,
        'date': '2023-01-01'
    },
    {
        'id': 5,
        'text': 'Mixed feelings about the new product from XYZ Corp. Some features are great, but others need improvement. #productlaunch #feedback',
        'username': '@tech_enthusiast',
        'location': 'Toronto, Canada',
        'followers': 8000,
        'category': 'Mixed',
        'likes': 500,
        'date': '2023-01-23'
    },
    {
        'id': 6,
        'text': 'Huge fan of XYZ Corp products and the new launch doesn\'t disappoint! #innovation #productlaunch',
        'username': '@loyal_customer',
        'location': 'Sydney, Australia',
        'followers': 10000,
        'category': 'Positive',
        'likes': 145,
        'date': '2023-01-10'
    },
    {
        'id': 7,
        'text': 'Not sure if the new product from XYZ Corp is worth the price tag. #pricey #productlaunch',
        'username': '@budgetshopper',
        'location': 'Paris, France',
        'followers': 5000,
        'category': 'Mixed',
        'likes': 286,
        'date':'2023-01-15'
    },
    {
        'id': 8,
        'text': 'Great customer service from XYZ Corp. They helped me resolve an issue with the new product quickly and efficiently. #customerservice #productlaunch',
        'username': '@happy_customer',
        'location': 'Berlin, Germany',
        'followers': 10000,
        'category': 'Positive',
        'likes': 25,
        'date':'2023-01-15'
    },
    {
        'id': 9,
        'text': 'New product from XYZ Corp is a game-changer! #innovation #productlaunch',
        'username': '@tech_reviewer',
        'location': 'Tokyo, Japan',
        'followers': 7500,
        'category': 'Positive',
        'likes': 500,
        'date': '2023-01-22'
    },
    {
        'id': 10,
        'text': 'Disappointed with the new product from XYZ Corp. It doesn\'t live up to the hype. #disappointed #productlaunch',
        'username': '@unsatisfied_customer',
        'location': 'Seoul, South Korea',
        'followers': 2500,
        'category': 'Negative',
        'likes': 80,
        'date': '2023-01-01'
    },
    {
    'id': 11,
    'text': 'Just tried the new product from XYZ Corp and it exceeded all my expectations! So impressed! #satisfied #newproduct',
    'username': '@happy_customer',
    'location': 'New York, NY',
    'followers': 5000,
    'category': 'Positive',
    'likes': 120,
    'date': '2023-01-05'
    },
    {
    'id': 12,
    'text': 'The new product from  XYZ Corp is just okay. It isn okay, not great or bad. #neutral #productreview',
    'username': '@indifferent_customer',
    'location': 'London, UK',
    'followers': 3000,
    'category': 'Neutral',
    'likes': 50,
    'date': '2023-01-10'
    },
    {
    'id': 13,
    'text': 'I have to say, I was skeptical about the new product from XYZ Corp, but it really surprised me! #pleasantlysurprised #newproduct',
    'username': '@openminded_customer',
    'location': 'Sydney, Australia',
    'followers': 4000,
    'category': 'Positive',
    'likes': 950,
    'date': '2023-01-15'
    },
    {
     'id': 15,
     'text': 'I am loving the new product from XYZ Corp! It is everything I wanted and more. #satisfiedcustomer #newproduct',
     'username': '@happy_customer2',
     'location': 'Los Angeles, CA',
     'followers': 6000,
     'category': 'Positive',
     'likes': 150,
     'date': '2023-01-25'
}
    
]

# Write tweet data to CSV file with UTF-8 encoding
with open('social_media_data.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['ID', 'Text', 'Username', 'Location', 'Followers', 'Category', 'Likes', 'Date'])
    for tweet in tweets:
        writer.writerow([tweet['id'], tweet['text'], tweet['username'], tweet['location'], tweet['followers'], tweet['category'], tweet['likes'], tweet['date']])
